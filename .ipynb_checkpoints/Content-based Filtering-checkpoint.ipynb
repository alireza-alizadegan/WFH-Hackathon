# %%
import numpy as np
import pandas as pd

# %%
user = np.random.randint(1, 5, 5).reshape(-1, 1)
user
# Out:
# array([[1],
#        [1],
#        [2],
#        [4],
#        [2]])

# %%
user_interest_df = pd.DataFrame(data=np.random.randint(1, 5, (100,5)), index=range(100)) 
user_interest_df
# Out:
#     0  1  2  3  4
# 0   4  3  2  4  4
# 1   2  3  2  3  1
# 2   2  2  1  4  2
# 3   1  3  3  1  1
# 4   4  3  1  4  1
# .. .. .. .. .. ..
# 95  4  1  3  4  3
# 96  1  3  1  1  4
# 97  2  3  1  2  4
# 98  2  2  3  2  3
# 99  4  4  1  1  1
#
# [100 rows x 5 columns]

# %%
project_interest_df = pd.DataFrame(data=np.random.randint(1, 5, (10,5)), index=range(10)) 
project_interest_df
# Out:
#    0  1  2  3  4
# 0  3  1  3  3  3
# 1  1  2  4  1  1
# 2  3  1  1  4  4
# 3  1  4  3  1  4
# 4  2  3  3  1  4
# 5  4  2  3  3  3
# 6  2  4  1  1  4
# 7  4  3  3  1  1
# 8  1  2  4  4  3
# 9  3  4  2  3  4

# %%
from sklearn.metrics.pairwise import cosine_similarity
def project_recommender(user, project_interest_df):
    
    # store similar projects in this dataframe
    similar_projects = pd.DataFrame(columns=['project', 'similarity'])
      
    # go through all projects
    for project in project_interest_df.index:
                
        # calculate similarity of two projects
        similarity = cosine_similarity(user_interest_df.iloc[user, :].values, project_interest_df.iloc[project, :].values)
        similar_projects.loc[len(similar_projects)] = [project, similarity[0][0]]

    return similar_project.sort_values(by='similarity', ascending=False)[1:]

project_recommender(10, project_interest_df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-62393a321d68> in <module>
#      14     return similar_project.sort_values(by='similarity', ascending=False)[1:]
#      15
# ---> 16 project_recommender(10, project_interest_df)
#
# <ipython-input-5-62393a321d68> in project_recommender(user, project_interest_df)
#       9
#      10         # calculate similarity of two projects
# ---> 11         similarity = cosine_similarity(user_interest_df.iloc[user, :].values, project_interest_df.iloc[project, :].values)
#      12         similar_projects.loc[len(similar_projects)] = [project, similarity[0][0]]
#      13
#
# ~\Anaconda3\lib\site-packages\sklearn\metrics\pairwise.py in cosine_similarity(X, Y, dense_output)
#    1025     # to avoid recursive import
#    1026
# -> 1027     X, Y = check_pairwise_arrays(X, Y)
#    1028
# ...

# %%
cosine_similarity([1, 2, 3], [1, 2, 3])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-99e1029c41ec> in <module>
# ----> 1 cosine_similarity([1, 2, 3], [1, 2, 3])
#
# ~\Anaconda3\lib\site-packages\sklearn\metrics\pairwise.py in cosine_similarity(X, Y, dense_output)
#    1025     # to avoid recursive import
#    1026
# -> 1027     X, Y = check_pairwise_arrays(X, Y)
#    1028
#    1029     X_normalized = normalize(X, copy=True)
#
# ~\Anaconda3\lib\site-packages\sklearn\metrics\pairwise.py in check_pairwise_arrays(X, Y, precomputed, dtype)
#     110     else:
#     111         X = check_array(X, accept_sparse='csr', dtype=dtype,
# --> 112                         estimator=estimator)
#     113         Y = check_array(Y, accept_sparse='csr', dtype=dtype,
#     114                         estimator=estimator)
#
# ...
